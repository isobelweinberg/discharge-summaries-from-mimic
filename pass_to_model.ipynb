# %%
from pass_to_model import generate
import os

input_dir = "data/mimic-iv-clinical-database-demo-2.2/subject-data"
output_dir = "data/mimic-iv-clinical-database-demo-2.2/output-data"
input_files = os.listdir(input_dir)

for file in input_files:
    print(file)
    output_file = file.replace('.txt', '.md')
    if output_file not in os.listdir(output_dir):
        response = generate(input_dir + "/" + file)
        with open(output_dir + "/" + output_file, "w+") as f:
            f.write(response)
        print(output_file + " created")
    else:
        print(output_file + " already exists")
# Out:
# 10000032.txt
# Output file already exists
# 10001217.txt
# Output file already exists
# 10001725.txt
# Output file already exists
# 10002428.txt
# Output file already exists
# 10002495.txt
# Output file already exists
# 10002930.txt
# Output file already exists
# 10003046.txt
# Output file already exists
# 10003400.txt
# Output file already exists
# 10004235.txt
# Output file already exists
# 10004422.txt
# Output file already exists
# 10004457.txt
# Output file already exists
# 10004720.txt
# Output file already exists
# 10004733.txt
# Output file already exists
# 10005348.txt
# Output file already exists
# 10005817.txt
# Output file created
# 10005866.txt
# Output file created
# 10005909.txt
# Output file created
# 10006053.txt
# Output file created
# 10006580.txt
# Output file created
# 10007058.txt
# Output file created
# 10007795.txt
# Output file created
# 10007818.txt
# Output file created
# 10007928.txt
# Output file created
# 10008287.txt
# Output file created
# 10008454.txt
# Output file created
# 10009035.txt
# Output file created
# 10009049.txt
# Output file created
# 10009628.txt
# Output file created
# 10010471.txt
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File c:\Users\Owner\Dropbox\Coding_projects\discharge-summaries-from-mimic\.myvenv\Lib\site-packages\google\api_core\grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75 try:
# ---> 76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
#
# File c:\Users\Owner\Dropbox\Coding_projects\discharge-summaries-from-mimic\.myvenv\Lib\site-packages\grpc\_channel.py:1181, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1175 (
#    1176     state,
#    1177     call,
#    1178 ) = self._blocking(
#    1179     request, timeout, metadata, credentials, wait_for_ready, compression
#    1180 )
# -> 1181 return _end_unary_response_blocking(state, call, False, None)
#
# File c:\Users\Owner\Dropbox\Coding_projects\discharge-summaries-from-mimic\.myvenv\Lib\site-packages\grpc\_channel.py:1006, in _end_unary_response_blocking(state, call, with_call, deadline)
#    1005 else:
# -> 1006     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.INVALID_ARGUMENT
# 	details = "Request contains an invalid argument."
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:216.58.213.10:443 {grpc_message:"Request contains an invalid argument.", grpc_status:3, created_time:"2024-11-02T16:54:10.7094285+00:00"}"
# >
#
# The above exception was the direct cause of the following exception:
#
# InvalidArgument                           Traceback (most recent call last)
# Cell In[2], line 11
#       9 print(file)
#      10 if file not in os.listdir(output_dir):
# ---> 11     response = generate(input_dir + "/" + file)
#      12     with open(output_dir + "/" + file, "w+") as f:
#      13         f.write(response)
#
# File c:\Users\Owner\Dropbox\Coding_projects\discharge-summaries-from-mimic\pass_to_model.py:46, in generate(filepath)
#      21 generation_config = {
#      22     "max_output_tokens": 8192,
#      23     "temperature": 1,
#      24     "top_p": 0.95,
#      25 }
#      27 safety_settings = [
#      28     SafetySetting(
#      29         category=SafetySetting.HarmCategory.HARM_CATEGORY_HATE_SPEECH,
#    (...)
#      43     ),
#      44     ]
# ---> 46 checktokens = model.count_tokens([document1, text1])
#      48 if checktokens.total_tokens > 2000000:
#      49     return "The input is too long. Please try again with a shorter input:" + filepath
#
# File c:\Users\Owner\Dropbox\Coding_projects\discharge-summaries-from-mimic\.myvenv\Lib\site-packages\vertexai\generative_models\_generative_models.py:861, in _GenerativeModel.count_tokens(self, contents, tools)
#     840 """Counts tokens.
#     841
#     842 Args:
#    (...)
#     855         total_billable_characters: The total number of billable characters counted across all instances from the request.
#     856 """
#     857 request = self._prepare_request(
#     858     contents=contents,
#     859     tools=tools,
#     860 )
# --> 861 return self._gapic_count_tokens(
#     862     prediction_resource_name=self._prediction_resource_name,
#     863     contents=request.contents,
#     864     system_instruction=request.system_instruction,
#     865     tools=request.tools,
#     866 )
#
# File c:\Users\Owner\Dropbox\Coding_projects\discharge-summaries-from-mimic\.myvenv\Lib\site-packages\vertexai\generative_models\_generative_models.py:3134, in GenerativeModel._gapic_count_tokens(self, prediction_resource_name, contents, system_instruction, tools)
#    3120 def _gapic_count_tokens(
#    3121     self,
#    3122     prediction_resource_name: str,
#    (...)
#    3125     tools: Optional[List[types_v1.Tool]] = None,
#    3126 ) -> types_v1.CountTokensResponse:
#    3127     request = types_v1.CountTokensRequest(
#    3128         endpoint=prediction_resource_name,
#    3129         model=prediction_resource_name,
#    (...)
#    3132         tools=tools,
#    3133     )
# -> 3134     return self._llm_utility_client.count_tokens(request=request)
#
# File c:\Users\Owner\Dropbox\Coding_projects\discharge-summaries-from-mimic\.myvenv\Lib\site-packages\google\cloud\aiplatform_v1\services\llm_utility_service\client.py:792, in LlmUtilityServiceClient.count_tokens(self, request, endpoint, instances, retry, timeout, metadata)
#     789 self._validate_universe_domain()
#     791 # Send the request.
# --> 792 response = rpc(
#     793     request,
#     794     retry=retry,
#     795     timeout=timeout,
#     796     metadata=metadata,
#     797 )
#     799 # Done; return the response.
#     800 return response
#
# File c:\Users\Owner\Dropbox\Coding_projects\discharge-summaries-from-mimic\.myvenv\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File c:\Users\Owner\Dropbox\Coding_projects\discharge-summaries-from-mimic\.myvenv\Lib\site-packages\google\api_core\grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# InvalidArgument: 400 Request contains an invalid argument.

# %%
# Out:
# ## Discharge Summary for Patient 10000032
#
# This patient had multiple admissions during the period 23/03/2180 to 09/09/2180. Below are individual discharge summaries for each admission:
#
# **Admission 1: 06/05/2180 - 07/05/2180**
#
# **Reason for Admission:** Transfer from another hospital. Presented with abnormal liver function tests including elevated AST (103 IU/L), ALT (98 IU/L), and ALP (114 IU/L).
#
# **Hospital Course:** Patient was placed in observation and started on a regimen of Heparin, Emtricitabine-Tenofovir, Raltegravir, Furosemide, Spironolactone, Albuterol inhaler, and Ipratropium Bromide nebulizer. A nicotine patch was also prescribed. Patient was found to have a slightly low hemoglobin (12.7 g/dL) and hematocrit (37.6%) but otherwise normal complete blood count. Urinalysis showed trace blood and protein. Urine culture showed mixed bacterial flora.
#
# **Discharge Diagnoses:**
# * Abnormal liver function tests
# * Anemia
#
# **Discharge Medications:**
# * Continue home medications.
# * Prescription for Furosemide and Spironolactone provided.
#
# **Discharge Instructions:**
# * Follow up with primary care physician for management of abnormal liver function tests and anemia.
#
# **Admission 2: 26/06/2180 - 27/06/2180**
#
# **Reason for Admission:** Emergency department presentation with hepatic coma and other major acute liver disorders.
#
# **Hospital Course:**  Patient was admitted to the Transplant service. Labs showed continued abnormal liver function tests with elevated AST (117 IU/L), ALT (158 IU/L), low albumin (2.7 g/dL), and slightly elevated creatinine (1.2 mg/dL). Urinalysis again showed trace blood and protein. Urine culture showed mixed bacterial flora with Enterococcus species sensitive to Ampicillin and Vancomycin, but resistant to Tetracycline. Patient was treated with Lactulose, Rifaximin, Calcium Carbonate, Emtricitabine-Tenofovir, Raltegravir, Sulfameth/Trimethoprim, Tiotropium Bromide, Furosemide, and albumin 25%.
#
# **Discharge Diagnoses:**
# * Hepatic coma
# * Other major acute liver disorders
#
# **Discharge Medications:**
# * Continue home medications.
#
# **Discharge Instructions:**
# * Follow up with primary care physician and hepatology for management of liver disease.
#
# **Admission 3: 23/07/2180 - 25/07/2180**
#
# **Reason for Admission:** Emergency department presentation with concerns for sepsis.
#
# **Hospital Course:**  Patient was admitted to MICU and started on Ceftriaxone, Lactulose, insulin, dextrose 50%, calcium gluconate, albumin 5%, Heparin, Rifaximin, Calcium Carbonate, Emtricitabine-Tenofovir, fluticasone propionate, Raltegravir, Tramadol, and Albuterol inhaler. Patient was found to have leukocytosis (16825 #/uL) and bandemia (220 #/uL). Blood cultures were negative. Patient was transferred to the Transplant service and ultimately discharged home.
#
# **Discharge Diagnoses:**
# * Sepsis
# * Abnormal liver function tests
#
# **Discharge Medications:**
# * Continue home medications.
#
# **Discharge Instructions:**
# * Follow up with primary care physician and hepatology for ongoing management of liver disease.
#
# **Admission 4: 05/08/2180 - 07/08/2180**
#
# **Reason for Admission:** Emergency department presentation with other disorders of the liver.
#
# **Hospital Course:**  Patient was admitted to the Transplant service and treated with Lactulose, Heparin, Rifaximin, Calcium Carbonate, Emtricitabine-Tenofovir, fluticasone propionate, Raltegravir, Tramadol, and Albuterol inhaler. Potassium and creatinine were slightly elevated on admission. Patient received treatment for hyperkalemia including Calcium Gluconate, insulin, dextrose 50%, and Sodium Polystyrene Sulfonate. Patient was discharged to hospice.
#
# **Discharge Diagnoses:**
# * Other disorders of the liver
# * Hyperkalemia
#
# **Discharge Medications:**
# * Continue home medications.
#
# **Discharge Instructions:**
# * Patient discharged to hospice care.
#
# **Note:** This discharge summary is based solely on the provided data and may not be comprehensive. Further details regarding the patient's medical history, physical examinations, and clinical course during each admission are not available and might be crucial for a more complete discharge summary.
